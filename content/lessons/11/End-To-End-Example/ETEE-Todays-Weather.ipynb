# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - Google Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - Darksky.net forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get a specified time's weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

#first I write these

def google_geocode(location):
    params = {'address' : location}
    url = 'http://maps.googleapis.com/maps/api/geocode/json'
    response = requests.get(url, params = params)
    geodata = response.json()
    return geodata

def darksky_weather(coords):
    key = '8bbd2056a66915d251dd59abdf906bd2' # sign up for your own key at https://darksky.net/dev 
    url='https://api.darksky.net/forecast/%s/%f,%f' % (key, coords['lat'], coords['lng'])
    response = requests.get(url)
    weather = response.json()
    return weather


# then test them here
geodata = google_geocode('Syracuse, NY')
coords =geodata['results'][0]['geometry']['location']
weather = darksky_weather(coords)
weather
# Out:
# {'alerts': [{'description': '...The flood warning continues for the following rivers in New York...\nOnondaga Lake At Liverpool affecting Onondaga County\n...The flood warning continues for the following rivers in New York..\nCayuga Lake At Ithaca affecting Tompkins County\nThe Flood Warning continues for\nThe Onondaga Lake At Liverpool.\n* Until Wednesday evening.\n* At 9 PM Sunday the stage was 367.0 feet.\n* Flood stage is 366.0 feet.\n* Minor flooding is occurring and Minor flooding is forecast.\n* Forecast...The river will continue to fall to below flood stage after 2 PM\nWednesday.\n* Impact...At 366.0 feet...Minor flood stage. Trails at Onondaga Lake Park are\nflooded. Marina usage is also impacted. Areas downstream of the lake, in the\nvicinity of Hayes Road, may be affected by flood waters.\n&&',
#    'expires': 1492041600,
#    'regions': ['Onondaga'],
#    'severity': 'warning',
#    'time': 1491790380,
#    'title': 'Flood Warning',
#    'uri': 'https://alerts.weather.gov/cap/wwacapget.php?x=NY12584A1FD1B4.FloodWarning.12584A4D4540NY.BGMFLSBGM.0527fa0f933ae67a660c4a214d9dec2f'}],
#  'currently': {'apparentTemperature': 56.23,
#   'cloudCover': 0.17,
#   'dewPoint': 30.92,
#   'humidity': 0.38,
#   'icon': 'clear-night',
#   'nearestStormBearing': 62,
#   'nearestStormDistance': 225,
#   'ozone': 330.38,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1015.65,
#   'summary': 'Clear',
#   'temperature': 56.23,
#   'time': 1491794986,
#   'visibility': 10,
#   'windBearing': 170,
#   'windSpeed': 5.98},
#  'daily': {'data': [{'apparentTemperatureMax': 69.84,
#     'apparentTemperatureMaxTime': 1491771600,
#     'apparentTemperatureMin': 35.55,
#     'apparentTemperatureMinTime': 1491728400,
#     'cloudCover': 0.21,
#     'dewPoint': 30.59,
#     'humidity': 0.45,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.45,
#     'ozone': 341.61,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1017.25,
#     'summary': 'Partly cloudy in the morning.',
#     'sunriseTime': 1491734004,
#     'sunsetTime': 1491781255,
#     'temperatureMax': 69.84,
#     'temperatureMaxTime': 1491771600,
#     'temperatureMin': 35.55,
#     'temperatureMinTime': 1491728400,
#     'time': 1491710400,
#     'visibility': 10,
#     'windBearing': 201,
#     'windSpeed': 2.51},
#    {'apparentTemperatureMax': 78.36,
#     'apparentTemperatureMaxTime': 1491850800,
#     'apparentTemperatureMin': 50.17,
#     'apparentTemperatureMinTime': 1491818400,
#     'cloudCover': 0.57,
#     'dewPoint': 44.31,
#     'humidity': 0.51,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.48,
#     'ozone': 323.66,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1016.51,
#     'summary': 'Mostly cloudy throughout the day.',
#     'sunriseTime': 1491820302,
#     'sunsetTime': 1491867725,
#     'temperatureMax': 78.36,
#     'temperatureMaxTime': 1491850800,
#     'temperatureMin': 50.17,
#     'temperatureMinTime': 1491818400,
#     'time': 1491796800,
#     'visibility': 10,
#     'windBearing': 178,
#     'windSpeed': 10.62},
#    {'apparentTemperatureMax': 72.91,
#     'apparentTemperatureMaxTime': 1491940800,
#     'apparentTemperatureMin': 58.05,
#     'apparentTemperatureMinTime': 1491904800,
#     'cloudCover': 0.64,
#     'dewPoint': 54.31,
#     'humidity': 0.71,
#     'icon': 'rain',
#     'moonPhase': 0.52,
#     'ozone': 335.76,
#     'precipIntensity': 0.0039,
#     'precipIntensityMax': 0.0096,
#     'precipIntensityMaxTime': 1491933600,
#     'precipProbability': 0.5,
#     'precipType': 'rain',
#     'pressure': 1017.73,
#     'summary': 'Light rain starting in the afternoon.',
#     'sunriseTime': 1491906601,
#     'sunsetTime': 1491954194,
#     'temperatureMax': 72.91,
#     'temperatureMaxTime': 1491940800,
#     'temperatureMin': 58.05,
#     'temperatureMinTime': 1491904800,
#     'time': 1491883200,
#     'visibility': 9.95,
#     'windBearing': 202,
#     'windSpeed': 8.17},
#    {'apparentTemperatureMax': 57.34,
#     'apparentTemperatureMaxTime': 1491969600,
#     'apparentTemperatureMin': 32.93,
#     'apparentTemperatureMinTime': 1492052400,
#     'cloudCover': 0.89,
#     'dewPoint': 41.13,
#     'humidity': 0.81,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.55,
#     'ozone': 357.16,
#     'precipIntensity': 0.0013,
#     'precipIntensityMax': 0.0054,
#     'precipIntensityMaxTime': 1491969600,
#     'precipProbability': 0.24,
#     'precipType': 'rain',
#     'pressure': 1022.67,
#     'summary': 'Mostly cloudy throughout the day.',
#     'sunriseTime': 1491992900,
#     'sunsetTime': 1492040664,
#     'temperatureMax': 57.34,
#     'temperatureMaxTime': 1491969600,
#     'temperatureMin': 39.74,
#     'temperatureMinTime': 1492052400,
#     'time': 1491969600,
#     'visibility': 10,
#     'windBearing': 268,
#     'windSpeed': 8.74},
#    {'apparentTemperatureMax': 53.04,
#     'apparentTemperatureMaxTime': 1492113600,
#     'apparentTemperatureMin': 28.25,
#     'apparentTemperatureMinTime': 1492074000,
#     'cloudCover': 0.6,
#     'dewPoint': 34.21,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.58,
#     'ozone': 369.77,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0009,
#     'precipIntensityMaxTime': 1492138800,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1027.42,
#     'summary': 'Partly cloudy throughout the day.',
#     'sunriseTime': 1492079200,
#     'sunsetTime': 1492127133,
#     'temperatureMax': 53.04,
#     'temperatureMaxTime': 1492113600,
#     'temperatureMin': 34.71,
#     'temperatureMinTime': 1492074000,
#     'time': 1492056000,
#     'visibility': 10,
#     'windBearing': 286,
#     'windSpeed': 6.9},
#    {'apparentTemperatureMax': 58.93,
#     'apparentTemperatureMaxTime': 1492200000,
#     'apparentTemperatureMin': 36.11,
#     'apparentTemperatureMinTime': 1492160400,
#     'cloudCover': 0.08,
#     'dewPoint': 37.09,
#     'humidity': 0.72,
#     'icon': 'clear-day',
#     'moonPhase': 0.61,
#     'ozone': 367.93,
#     'precipIntensity': 0.0017,
#     'precipIntensityMax': 0.0024,
#     'precipIntensityMaxTime': 1492174800,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'pressure': 1025.97,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1492165501,
#     'sunsetTime': 1492213603,
#     'temperatureMax': 58.93,
#     'temperatureMaxTime': 1492200000,
#     'temperatureMin': 36.11,
#     'temperatureMinTime': 1492160400,
#     'time': 1492142400,
#     'windBearing': 317,
#     'windSpeed': 1.94},
#    {'apparentTemperatureMax': 65.77,
#     'apparentTemperatureMaxTime': 1492282800,
#     'apparentTemperatureMin': 36.56,
#     'apparentTemperatureMinTime': 1492246800,
#     'cloudCover': 0.24,
#     'dewPoint': 43.3,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'moonPhase': 0.64,
#     'ozone': 340.09,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0012,
#     'precipIntensityMaxTime': 1492311600,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1024.64,
#     'summary': 'Partly cloudy starting in the afternoon.',
#     'sunriseTime': 1492251802,
#     'sunsetTime': 1492300073,
#     'temperatureMax': 65.77,
#     'temperatureMaxTime': 1492282800,
#     'temperatureMin': 39.02,
#     'temperatureMinTime': 1492246800,
#     'time': 1492228800,
#     'windBearing': 172,
#     'windSpeed': 5.39},
#    {'apparentTemperatureMax': 66.23,
#     'apparentTemperatureMaxTime': 1492376400,
#     'apparentTemperatureMin': 56.61,
#     'apparentTemperatureMinTime': 1492340400,
#     'cloudCover': 0.78,
#     'dewPoint': 56.2,
#     'humidity': 0.84,
#     'icon': 'rain',
#     'moonPhase': 0.67,
#     'ozone': 330.25,
#     'precipIntensity': 0.0033,
#     'precipIntensityMax': 0.0067,
#     'precipIntensityMaxTime': 1492376400,
#     'precipProbability': 0.32,
#     'precipType': 'rain',
#     'pressure': 1015.11,
#     'summary': 'Drizzle starting in the afternoon, continuing until evening.',
#     'sunriseTime': 1492338104,
#     'sunsetTime': 1492386543,
#     'temperatureMax': 66.23,
#     'temperatureMaxTime': 1492376400,
#     'temperatureMin': 56.61,
#     'temperatureMinTime': 1492340400,
#     'time': 1492315200,
#     'windBearing': 231,
#     'windSpeed': 9.25}],
#   'icon': 'rain',
#   'summary': 'Drizzle on Tuesday through Sunday, with temperatures falling to 53°F on Thursday.'},
#  'flags': {'isd-stations': ['718200-99999',
#    '725146-54773',
#    '725146-99999',
#    '725155-94761',
#    '725155-99999',
#    '725190-14771',
#    '725194-54778',
#    '725194-99999',
#    '725195-99999',
#    '725196-14717',
#    '725196-64775',
#    '725197-94794',
#    '997264-99999',
#    '999999-14771',
#    '999999-64758',
#    '999999-94781'],
#   'lamp-stations': ['KFZY', 'KRME', 'KSYR'],
#   'madis-stations': ['AS511',
#    'AU364',
#    'AU822',
#    'C2055',
#    'C6839',
#    'C8614',
#    'C9173',
#    'D6725',
#    'D8028',
#    'E0795',
#    'E1986',
#    'E5907',
#    'E6659',
#    'E7565',
#    'GICN6',
#    'KSYR'],
#   'sources': ['lamp',
#    'gfs',
#    'cmc',
#    'nam',
#    'rap',
#    'rtma',
#    'sref',
#    'fnmoc',
#    'isd',
#    'madis',
#    'nearest-precip',
#    'nwspa',
#    'darksky'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 60.31,
#     'cloudCover': 0.14,
#     'dewPoint': 32.59,
#     'humidity': 0.35,
#     'icon': 'clear-night',
#     'ozone': 330.97,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.49,
#     'summary': 'Clear',
#     'temperature': 60.31,
#     'time': 1491793200,
#     'visibility': 10,
#     'windBearing': 167,
#     'windSpeed': 4.64},
#    {'apparentTemperature': 54.99,
#     'cloudCover': 0.19,
#     'dewPoint': 31.63,
#     'humidity': 0.41,
#     'icon': 'clear-night',
#     'ozone': 329.79,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.81,
#     'summary': 'Clear',
#     'temperature': 54.99,
#     'time': 1491796800,
#     'visibility': 10,
#     'windBearing': 171,
#     'windSpeed': 7.34},
#    {'apparentTemperature': 53.79,
#     'cloudCover': 0.22,
#     'dewPoint': 33.29,
#     'humidity': 0.46,
#     'icon': 'clear-night',
#     'ozone': 328.24,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.3,
#     'summary': 'Clear',
#     'temperature': 53.79,
#     'time': 1491800400,
#     'visibility': 10,
#     'windBearing': 171,
#     'windSpeed': 8.54},
#    {'apparentTemperature': 52.9,
#     'cloudCover': 0.24,
#     'dewPoint': 34.61,
#     'humidity': 0.5,
#     'icon': 'clear-night',
#     'ozone': 326.99,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.83,
#     'summary': 'Clear',
#     'temperature': 52.9,
#     'time': 1491804000,
#     'visibility': 10,
#     'windBearing': 171,
#     'windSpeed': 9.51},
#    {'apparentTemperature': 52.44,
#     'cloudCover': 0.29,
#     'dewPoint': 35.58,
#     'humidity': 0.53,
#     'icon': 'partly-cloudy-night',
#     'ozone': 326.36,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.14,
#     'summary': 'Partly Cloudy',
#     'temperature': 52.44,
#     'time': 1491807600,
#     'visibility': 10,
#     'windBearing': 172,
#     'windSpeed': 10.05},
#    {'apparentTemperature': 52,
#     'cloudCover': 0.36,
#     'dewPoint': 35.87,
#     'humidity': 0.54,
#     'icon': 'partly-cloudy-night',
#     'ozone': 326.02,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.23,
#     'summary': 'Partly Cloudy',
#     'temperature': 52,
#     'time': 1491811200,
#     'visibility': 10,
#     'windBearing': 170,
#     'windSpeed': 10.41},
#    {'apparentTemperature': 50.3,
#     'cloudCover': 0.43,
#     'dewPoint': 34.99,
#     'humidity': 0.56,
#     'icon': 'partly-cloudy-night',
#     'ozone': 325.68,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.66,
#     'summary': 'Partly Cloudy',
#     'temperature': 50.3,
#     'time': 1491814800,
#     'visibility': 10,
#     'windBearing': 169,
#     'windSpeed': 10.86},
#    {'apparentTemperature': 50.17,
#     'cloudCover': 0.63,
#     'dewPoint': 35.29,
#     'humidity': 0.56,
#     'icon': 'partly-cloudy-night',
#     'ozone': 325.28,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.67,
#     'summary': 'Mostly Cloudy',
#     'temperature': 50.17,
#     'time': 1491818400,
#     'visibility': 10,
#     'windBearing': 168,
#     'windSpeed': 10.95},
#    {'apparentTemperature': 50.82,
#     'cloudCover': 0.7,
#     'dewPoint': 36.19,
#     'humidity': 0.57,
#     'icon': 'partly-cloudy-day',
#     'ozone': 324.86,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.73,
#     'summary': 'Mostly Cloudy',
#     'temperature': 50.82,
#     'time': 1491822000,
#     'visibility': 10,
#     'windBearing': 167,
#     'windSpeed': 11.03},
#    {'apparentTemperature': 53.09,
#     'cloudCover': 0.74,
#     'dewPoint': 37.92,
#     'humidity': 0.56,
#     'icon': 'partly-cloudy-day',
#     'ozone': 324.35,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.67,
#     'summary': 'Mostly Cloudy',
#     'temperature': 53.09,
#     'time': 1491825600,
#     'visibility': 10,
#     'windBearing': 170,
#     'windSpeed': 11.26},
#    {'apparentTemperature': 56.92,
#     'cloudCover': 0.72,
#     'dewPoint': 39.83,
#     'humidity': 0.53,
#     'icon': 'partly-cloudy-day',
#     'ozone': 323.63,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.37,
#     'summary': 'Mostly Cloudy',
#     'temperature': 56.92,
#     'time': 1491829200,
#     'visibility': 10,
#     'windBearing': 176,
#     'windSpeed': 11.69},
#    {'apparentTemperature': 61.87,
#     'cloudCover': 0.67,
#     'dewPoint': 42.74,
#     'humidity': 0.49,
#     'icon': 'partly-cloudy-day',
#     'ozone': 322.8,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.93,
#     'summary': 'Mostly Cloudy',
#     'temperature': 61.87,
#     'time': 1491832800,
#     'visibility': 10,
#     'windBearing': 182,
#     'windSpeed': 12.18},
#    {'apparentTemperature': 66.47,
#     'cloudCover': 0.48,
#     'dewPoint': 45.89,
#     'humidity': 0.47,
#     'icon': 'partly-cloudy-day',
#     'ozone': 322.13,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.5,
#     'summary': 'Partly Cloudy',
#     'temperature': 66.47,
#     'time': 1491836400,
#     'visibility': 10,
#     'windBearing': 181,
#     'windSpeed': 12.15},
#    {'apparentTemperature': 70.69,
#     'cloudCover': 0.63,
#     'dewPoint': 48.83,
#     'humidity': 0.46,
#     'icon': 'partly-cloudy-day',
#     'ozone': 321.8,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.15,
#     'summary': 'Mostly Cloudy',
#     'temperature': 70.69,
#     'time': 1491840000,
#     'visibility': 10,
#     'windBearing': 185,
#     'windSpeed': 12.34},
#    {'apparentTemperature': 74.2,
#     'cloudCover': 0.63,
#     'dewPoint': 51.07,
#     'humidity': 0.44,
#     'icon': 'partly-cloudy-day',
#     'ozone': 321.61,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.84,
#     'summary': 'Mostly Cloudy',
#     'temperature': 74.2,
#     'time': 1491843600,
#     'visibility': 10,
#     'windBearing': 187,
#     'windSpeed': 12.45},
#    {'apparentTemperature': 77.17,
#     'cloudCover': 0.66,
#     'dewPoint': 52.91,
#     'humidity': 0.43,
#     'icon': 'partly-cloudy-day',
#     'ozone': 321.29,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.58,
#     'summary': 'Mostly Cloudy',
#     'temperature': 77.17,
#     'time': 1491847200,
#     'visibility': 10,
#     'windBearing': 185,
#     'windSpeed': 12.52},
#    {'apparentTemperature': 78.36,
#     'cloudCover': 0.68,
#     'dewPoint': 54.01,
#     'humidity': 0.43,
#     'icon': 'partly-cloudy-day',
#     'ozone': 320.45,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.31,
#     'summary': 'Mostly Cloudy',
#     'temperature': 78.36,
#     'time': 1491850800,
#     'visibility': 10,
#     'windBearing': 186,
#     'windSpeed': 12.64},
#    {'apparentTemperature': 77.73,
#     'cloudCover': 0.7,
#     'dewPoint': 53.85,
#     'humidity': 0.44,
#     'icon': 'partly-cloudy-day',
#     'ozone': 319.48,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.08,
#     'summary': 'Mostly Cloudy',
#     'temperature': 77.73,
#     'time': 1491854400,
#     'visibility': 10,
#     'windBearing': 187,
#     'windSpeed': 12.17},
#    {'apparentTemperature': 76.46,
#     'cloudCover': 0.72,
#     'dewPoint': 52.5,
#     'humidity': 0.43,
#     'icon': 'partly-cloudy-day',
#     'ozone': 319.23,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.01,
#     'summary': 'Mostly Cloudy',
#     'temperature': 76.46,
#     'time': 1491858000,
#     'visibility': 10,
#     'windBearing': 189,
#     'windSpeed': 12.04},
#    {'apparentTemperature': 74.28,
#     'cloudCover': 0.7,
#     'dewPoint': 52.11,
#     'humidity': 0.46,
#     'icon': 'partly-cloudy-day',
#     'ozone': 320.39,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.31,
#     'summary': 'Mostly Cloudy',
#     'temperature': 74.28,
#     'time': 1491861600,
#     'visibility': 10,
#     'windBearing': 186,
#     'windSpeed': 11.22},
#    {'apparentTemperature': 70.8,
#     'cloudCover': 0.67,
#     'dewPoint': 51.88,
#     'humidity': 0.51,
#     'icon': 'partly-cloudy-day',
#     'ozone': 322.28,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.9,
#     'summary': 'Mostly Cloudy',
#     'temperature': 70.8,
#     'time': 1491865200,
#     'visibility': 10,
#     'windBearing': 180,
#     'windSpeed': 9.96},
#    {'apparentTemperature': 67.74,
#     'cloudCover': 0.65,
#     'dewPoint': 51.18,
#     'humidity': 0.55,
#     'icon': 'partly-cloudy-night',
#     'ozone': 323.68,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.22,
#     'summary': 'Mostly Cloudy',
#     'temperature': 67.74,
#     'time': 1491868800,
#     'visibility': 10,
#     'windBearing': 175,
#     'windSpeed': 9.05},
#    {'apparentTemperature': 65.33,
#     'cloudCover': 0.64,
#     'dewPoint': 50.49,
#     'humidity': 0.59,
#     'icon': 'partly-cloudy-night',
#     'ozone': 323.98,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.6,
#     'summary': 'Mostly Cloudy',
#     'temperature': 65.33,
#     'time': 1491872400,
#     'visibility': 10,
#     'windBearing': 176,
#     'windSpeed': 8.66},
#    {'apparentTemperature': 64.39,
#     'cloudCover': 0.73,
#     'dewPoint': 50.49,
#     'humidity': 0.61,
#     'icon': 'partly-cloudy-night',
#     'ozone': 323.79,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.06,
#     'summary': 'Mostly Cloudy',
#     'temperature': 64.39,
#     'time': 1491876000,
#     'visibility': 10,
#     'windBearing': 181,
#     'windSpeed': 8.84},
#    {'apparentTemperature': 63.19,
#     'cloudCover': 0.65,
#     'dewPoint': 50.23,
#     'humidity': 0.63,
#     'icon': 'partly-cloudy-night',
#     'ozone': 323.73,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.42,
#     'summary': 'Mostly Cloudy',
#     'temperature': 63.19,
#     'time': 1491879600,
#     'visibility': 10,
#     'windBearing': 183,
#     'windSpeed': 9.01},
#    {'apparentTemperature': 62.26,
#     'cloudCover': 0.62,
#     'dewPoint': 50.09,
#     'humidity': 0.64,
#     'icon': 'partly-cloudy-night',
#     'ozone': 323.88,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.58,
#     'summary': 'Mostly Cloudy',
#     'temperature': 62.26,
#     'time': 1491883200,
#     'visibility': 10,
#     'windBearing': 182,
#     'windSpeed': 8.97},
#    {'apparentTemperature': 61.25,
#     'cloudCover': 0.57,
#     'dewPoint': 49.81,
#     'humidity': 0.66,
#     'icon': 'partly-cloudy-night',
#     'ozone': 324.16,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.61,
#     'summary': 'Partly Cloudy',
#     'temperature': 61.25,
#     'time': 1491886800,
#     'visibility': 10,
#     'windBearing': 178,
#     'windSpeed': 8.91},
#    {'apparentTemperature': 60.45,
#     'cloudCover': 0.54,
#     'dewPoint': 49.61,
#     'humidity': 0.67,
#     'icon': 'partly-cloudy-night',
#     'ozone': 325.04,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.61,
#     'summary': 'Partly Cloudy',
#     'temperature': 60.45,
#     'time': 1491890400,
#     'visibility': 10,
#     'windBearing': 176,
#     'windSpeed': 8.89},
#    {'apparentTemperature': 59.88,
#     'cloudCover': 0.53,
#     'dewPoint': 49.56,
#     'humidity': 0.69,
#     'icon': 'partly-cloudy-night',
#     'ozone': 326.82,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.47,
#     'summary': 'Partly Cloudy',
#     'temperature': 59.88,
#     'time': 1491894000,
#     'visibility': 10,
#     'windBearing': 175,
#     'windSpeed': 8.88},
#    {'apparentTemperature': 58.59,
#     'cloudCover': 0.51,
#     'dewPoint': 48.91,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-night',
#     'ozone': 329.2,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.33,
#     'summary': 'Partly Cloudy',
#     'temperature': 58.59,
#     'time': 1491897600,
#     'visibility': 10,
#     'windBearing': 174,
#     'windSpeed': 8.87},
#    {'apparentTemperature': 58.19,
#     'cloudCover': 0.53,
#     'dewPoint': 48.81,
#     'humidity': 0.71,
#     'icon': 'partly-cloudy-night',
#     'ozone': 331.69,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.33,
#     'summary': 'Partly Cloudy',
#     'temperature': 58.19,
#     'time': 1491901200,
#     'visibility': 10,
#     'windBearing': 174,
#     'windSpeed': 8.97},
#    {'apparentTemperature': 58.05,
#     'cloudCover': 0.56,
#     'dewPoint': 48.97,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 334.56,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.57,
#     'summary': 'Partly Cloudy',
#     'temperature': 58.05,
#     'time': 1491904800,
#     'visibility': 10,
#     'windBearing': 172,
#     'windSpeed': 9.15},
#    {'apparentTemperature': 58.44,
#     'cloudCover': 0.59,
#     'dewPoint': 49.57,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-day',
#     'ozone': 337.54,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.92,
#     'summary': 'Partly Cloudy',
#     'temperature': 58.44,
#     'time': 1491908400,
#     'visibility': 10,
#     'windBearing': 171,
#     'windSpeed': 9.32},
#    {'apparentTemperature': 59.22,
#     'cloudCover': 0.62,
#     'dewPoint': 50.2,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-day',
#     'ozone': 339.44,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1018.19,
#     'summary': 'Mostly Cloudy',
#     'temperature': 59.22,
#     'time': 1491912000,
#     'visibility': 10,
#     'windBearing': 175,
#     'windSpeed': 9.27},
#    {'apparentTemperature': 61.76,
#     'cloudCover': 0.61,
#     'dewPoint': 51.8,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-day',
#     'ozone': 339.27,
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1018.26,
#     'summary': 'Mostly Cloudy',
#     'temperature': 61.76,
#     'time': 1491915600,
#     'visibility': 10,
#     'windBearing': 186,
#     'windSpeed': 9},
#    {'apparentTemperature': 65.26,
#     'cloudCover': 0.6,
#     'dewPoint': 53.88,
#     'humidity': 0.67,
#     'icon': 'partly-cloudy-day',
#     'ozone': 338.01,
#     'precipIntensity': 0.0025,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'pressure': 1018.25,
#     'summary': 'Mostly Cloudy',
#     'temperature': 65.26,
#     'time': 1491919200,
#     'visibility': 10,
#     'windBearing': 203,
#     'windSpeed': 9.3},
#    {'apparentTemperature': 68.07,
#     'cloudCover': 0.61,
#     'dewPoint': 55.57,
#     'humidity': 0.64,
#     'icon': 'partly-cloudy-day',
#     'ozone': 337.4,
#     'precipIntensity': 0.004,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'pressure': 1018.19,
#     'summary': 'Mostly Cloudy',
#     'temperature': 68.07,
#     'time': 1491922800,
#     'visibility': 10,
#     'windBearing': 211,
#     'windSpeed': 9.96},
#    {'apparentTemperature': 69.63,
#     'cloudCover': 0.68,
#     'dewPoint': 56.78,
#     'humidity': 0.64,
#     'icon': 'rain',
#     'ozone': 338.46,
#     'precipIntensity': 0.006,
#     'precipProbability': 0.27,
#     'precipType': 'rain',
#     'pressure': 1018.09,
#     'summary': 'Drizzle',
#     'temperature': 69.63,
#     'time': 1491926400,
#     'visibility': 10,
#     'windBearing': 211,
#     'windSpeed': 10.08},
#    {'apparentTemperature': 69.67,
#     'cloudCover': 0.77,
#     'dewPoint': 56.96,
#     'humidity': 0.64,
#     'icon': 'rain',
#     'ozone': 340.16,
#     'precipIntensity': 0.0082,
#     'precipProbability': 0.42,
#     'precipType': 'rain',
#     'pressure': 1017.93,
#     'summary': 'Drizzle',
#     'temperature': 69.67,
#     'time': 1491930000,
#     'visibility': 10,
#     'windBearing': 207,
#     'windSpeed': 9.89},
#    {'apparentTemperature': 70.47,
#     'cloudCover': 0.83,
#     'dewPoint': 58.03,
#     'humidity': 0.65,
#     'icon': 'rain',
#     'ozone': 341.16,
#     'precipIntensity': 0.0096,
#     'precipProbability': 0.5,
#     'precipType': 'rain',
#     'pressure': 1017.71,
#     'summary': 'Light Rain',
#     'temperature': 70.47,
#     'time': 1491933600,
#     'visibility': 10,
#     'windBearing': 206,
#     'windSpeed': 10.01},
#    {'apparentTemperature': 71.85,
#     'cloudCover': 0.8,
#     'dewPoint': 59.59,
#     'humidity': 0.65,
#     'icon': 'rain',
#     'ozone': 340.63,
#     'precipIntensity': 0.0094,
#     'precipProbability': 0.5,
#     'precipType': 'rain',
#     'pressure': 1017.31,
#     'summary': 'Light Rain',
#     'temperature': 71.85,
#     'time': 1491937200,
#     'visibility': 10,
#     'windBearing': 210,
#     'windSpeed': 10.44},
#    {'apparentTemperature': 72.91,
#     'cloudCover': 0.72,
#     'dewPoint': 61.02,
#     'humidity': 0.66,
#     'icon': 'rain',
#     'ozone': 339.4,
#     'precipIntensity': 0.0082,
#     'precipProbability': 0.42,
#     'precipType': 'rain',
#     'pressure': 1016.84,
#     'summary': 'Drizzle',
#     'temperature': 72.91,
#     'time': 1491940800,
#     'visibility': 9.99,
#     'windBearing': 217,
#     'windSpeed': 11.04},
#    {'apparentTemperature': 71.99,
#     'cloudCover': 0.67,
#     'dewPoint': 61.09,
#     'humidity': 0.69,
#     'icon': 'rain',
#     'ozone': 338.53,
#     'precipIntensity': 0.0072,
#     'precipProbability': 0.35,
#     'precipType': 'rain',
#     'pressure': 1016.61,
#     'summary': 'Drizzle',
#     'temperature': 71.99,
#     'time': 1491944400,
#     'visibility': 9.96,
#     'windBearing': 222,
#     'windSpeed': 10.9},
#    {'apparentTemperature': 68.69,
#     'cloudCover': 0.64,
#     'dewPoint': 59.75,
#     'humidity': 0.73,
#     'icon': 'rain',
#     'ozone': 338.57,
#     'precipIntensity': 0.0064,
#     'precipProbability': 0.3,
#     'precipType': 'rain',
#     'pressure': 1016.77,
#     'summary': 'Drizzle',
#     'temperature': 68.69,
#     'time': 1491948000,
#     'visibility': 9.86,
#     'windBearing': 229,
#     'windSpeed': 9.23},
#    {'apparentTemperature': 65,
#     'cloudCover': 0.62,
#     'dewPoint': 58.28,
#     'humidity': 0.79,
#     'icon': 'rain',
#     'ozone': 338.96,
#     'precipIntensity': 0.0056,
#     'precipProbability': 0.25,
#     'precipType': 'rain',
#     'pressure': 1017.19,
#     'summary': 'Drizzle',
#     'temperature': 65,
#     'time': 1491951600,
#     'visibility': 9.73,
#     'windBearing': 236,
#     'windSpeed': 7.36},
#    {'apparentTemperature': 62.27,
#     'cloudCover': 0.61,
#     'dewPoint': 57.13,
#     'humidity': 0.83,
#     'icon': 'rain',
#     'ozone': 339.21,
#     'precipIntensity': 0.0053,
#     'precipProbability': 0.23,
#     'precipType': 'rain',
#     'pressure': 1017.67,
#     'summary': 'Drizzle',
#     'temperature': 62.27,
#     'time': 1491955200,
#     'visibility': 9.67,
#     'windBearing': 242,
#     'windSpeed': 6.23},
#    {'apparentTemperature': 61.15,
#     'cloudCover': 0.62,
#     'dewPoint': 56.64,
#     'humidity': 0.85,
#     'icon': 'rain',
#     'ozone': 339.05,
#     'precipIntensity': 0.0056,
#     'precipProbability': 0.25,
#     'precipType': 'rain',
#     'pressure': 1018.21,
#     'summary': 'Drizzle',
#     'temperature': 61.15,
#     'time': 1491958800,
#     'visibility': 9.75,
#     'windBearing': 243,
#     'windSpeed': 6.35},
#    {'apparentTemperature': 60.35,
#     'cloudCover': 0.68,
#     'dewPoint': 56.05,
#     'humidity': 0.86,
#     'icon': 'rain',
#     'ozone': 338.74,
#     'precipIntensity': 0.0063,
#     'precipProbability': 0.29,
#     'precipType': 'rain',
#     'pressure': 1018.78,
#     'summary': 'Drizzle',
#     'temperature': 60.35,
#     'time': 1491962400,
#     'visibility': 9.89,
#     'windBearing': 239,
#     'windSpeed': 6.82},
#    {'apparentTemperature': 59.4,
#     'cloudCover': 0.73,
#     'dewPoint': 55.32,
#     'humidity': 0.86,
#     'icon': 'rain',
#     'ozone': 338.48,
#     'precipIntensity': 0.0064,
#     'precipProbability': 0.3,
#     'precipType': 'rain',
#     'pressure': 1019.17,
#     'summary': 'Drizzle',
#     'temperature': 59.4,
#     'time': 1491966000,
#     'visibility': 10,
#     'windBearing': 238,
#     'windSpeed': 7.03}],
#   'icon': 'partly-cloudy-day',
#   'summary': 'Mostly cloudy starting later tonight.'},
#  'latitude': 43.048122,
#  'longitude': -76.147424,
#  'minutely': {'data': [{'precipIntensity': 0,
#     'precipProbability': 0,
#     'time': 1491794940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795120},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795180},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795240},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795540},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795600},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795660},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795720},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795780},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795840},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795900},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491795960},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796020},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796080},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796140},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796200},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796260},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796320},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796380},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796440},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796500},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796560},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796620},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796680},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796740},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796800},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796860},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796920},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491796980},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797040},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797100},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797160},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797220},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797280},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797340},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797400},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797460},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491797940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798120},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798180},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798240},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1491798540}],
#   'icon': 'clear-night',
#   'summary': 'Clear for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %%
import requests
# Now I can write the entire program...
location = 'Syracuse, NY'
geodata = google_geocode(location)
coords =geodata['data'][0]['geometry']['location']
weather = darksky_weather(coords)
current = weather['time']
print("Current conditions in %s are %s with a temperature of %.0f degrees." % 
      (location, current['summary'], current['temperature']))
# Out:
# Where are you? (eg. Syracuse, NY) : Dallas, TX
# Current conditions in Dallas, TX are Partly Cloudy with a temperature of 74 degrees.
